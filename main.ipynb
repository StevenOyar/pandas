# %%
# the importation of the libraries needed
import pandas as pd 
import matplotlib.pyplot as plt

# %%
# read csv file
homeless_df = pd.read_csv('homeless.csv')

# %%
# getting the first 10 rows of the df
print(homeless_df.head(10))
# Out:
#    Unnamed: 0              region                 state  individuals  \
# 0           0  East South Central               Alabama       2570.0
# 1           1             Pacific                Alaska       1434.0
# 2           2            Mountain               Arizona       7259.0
# 3           3  West South Central              Arkansas       2280.0
# 4           4             Pacific            California     109008.0
# 5           5            Mountain              Colorado       7607.0
# 6           6         New England           Connecticut       2280.0
# 7           7      South Atlantic              Delaware        708.0
# 8           8      South Atlantic  District of Columbia       3770.0
# 9           9      South Atlantic               Florida      21443.0
#
#    family_members  state_pop
# 0           864.0    4887681
# 1           582.0     735139
# 2          2606.0    7158024
# 3           432.0    3009733
# 4         20964.0   39461588
# ...

# %%
#  getting index, columns and shape of the dataframe
print(homeless_df.index)
print(homeless_df.columns)
print(homeless_df.shape)
# Out:
# RangeIndex(start=0, stop=51, step=1)
# Index(['Unnamed: 0', 'region', 'state', 'individuals', 'family_members',
#        'state_pop'],
#       dtype='str')
# (51, 6)

# %%
#  getting the description statistics of the df
print(homeless_df.describe())
# Out:
#        Unnamed: 0    individuals  family_members     state_pop
# count   51.000000      51.000000       51.000000  5.100000e+01
# mean    25.000000    7225.784314     3504.882353  6.405637e+06
# std     14.866069   15991.025083     7805.411811  7.327258e+06
# min      0.000000     434.000000       75.000000  5.776010e+05
# 25%     12.500000    1446.500000      592.000000  1.777414e+06
# 50%     25.000000    3082.000000     1482.000000  4.461153e+06
# 75%     37.500000    6781.500000     3196.000000  7.340946e+06
# max     50.000000  109008.000000    52070.000000  3.946159e+07
